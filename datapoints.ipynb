# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

# %%
dg_2_approx = "2-approx.csv"
dg_brute_force = "dg.csv"
wdg_linear = "wdg_linear.csv"
wdg_round = "wdg_round.csv"
iwdg = "iwdg.csv"
lazy = "lazy.csv"
cbs = "cbs.csv"
cbsN = "cbsN.csv"
dgN = "dgN.csv"
wdgN = "wdgN.csv"
lazyN = "lazyN.csv"
collisionMax = "max.csv"

# %%
cbs_time = []
cbs_generate = []
cbs_expand = []
with open(cbs, 'r', encoding="utf-8") as csvfile:
    cbs_reader = csv.reader(csvfile)
    for i,row in enumerate(cbs_reader):
        if i != 0 and i != 42:
            cbs_time.append(float(row[2]))
            cbs_generate.append(int(row[3]))
            cbs_expand.append(int(row[4]))

# %%
dg_2_approx_time = []
dg_2_approx_generate = []
dg_2_approx_expand = []
with open(dg_2_approx, 'r', encoding="utf-8") as csvfile:
    dg_2_approx_reader = csv.reader(csvfile)
    for i,row in enumerate(dg_2_approx_reader):
        if i != 0 and i != 42:
            dg_2_approx_time.append(float(row[2]))
            dg_2_approx_generate.append(int(row[3]))
            dg_2_approx_expand.append(int(row[4]))

# %%
dg_brute_force_time = []
dg_brute_force_generate = []
dg_brute_force_expand = []
with open(dg_brute_force, 'r', encoding="utf-8") as csvfile:
    dg_brute_force_reader = csv.reader(csvfile)
    for i,row in enumerate(dg_brute_force_reader):
        if i != 0 and i != 42:
            dg_brute_force_time.append(float(row[2]))
            dg_brute_force_generate.append(int(row[3]))
            dg_brute_force_expand.append(int(row[4]))

# %%
wdg_linear_time = []
wdg_linear_generate = []
wdg_linear_expand = []
with open(wdg_linear, 'r', encoding="utf-8") as csvfile:
    wdg_linear_reader = csv.reader(csvfile)
    for i,row in enumerate(wdg_linear_reader):
        if i != 0 and i != 42:
            wdg_linear_time.append(float(row[2]))
            wdg_linear_generate.append(int(row[3]))
            wdg_linear_expand.append(int(row[4]))

# %%
wdg_round_time = []
wdg_round_generate = []
wdg_round_expand = []
with open(wdg_round, 'r', encoding="utf-8") as csvfile:
    wdg_round_reader = csv.reader(csvfile)
    for i,row in enumerate(wdg_round_reader):
        if i != 0 and i != 42:
            wdg_round_time.append(float(row[2]))
            wdg_round_generate.append(int(row[3]))
            wdg_round_expand.append(int(row[4]))

# %%
iwdg_time = []
iwdg_generate = []
iwdg_expand = []
with open(iwdg, 'r', encoding="utf-8") as csvfile:
    iwdg_reader = csv.reader(csvfile)
    for i,row in enumerate(iwdg_reader):
        if i != 0 and i != 42:
            iwdg_time.append(float(row[2]))
            iwdg_generate.append(int(row[3]))
            iwdg_expand.append(int(row[4]))

# %%
lazy_time = []
lazy_generate = []
lazy_expand = []
with open(lazy, 'r', encoding="utf-8") as csvfile:
    lazy_reader = csv.reader(csvfile)
    for i,row in enumerate(lazy_reader):
        if i != 0 and i != 42:
            lazy_time.append(float(row[2]))
            lazy_generate.append(int(row[3]))
            lazy_expand.append(int(row[4]))

# %%
cbsN_time = []
cbsN_generate = []
cbsN_expand = []
with open(cbsN, 'r', encoding="utf-8") as csvfile:
    cbsN_reader = csv.reader(csvfile)
    for i,row in enumerate(cbsN_reader):
        if i != 0:
            cbsN_time.append(float(row[2]))
            cbsN_generate.append(int(row[3]))
            cbsN_expand.append(int(row[4]))

# %%
cbsN2_time = []
cbsN2_generate = []
cbsN2_expand = []
with open(cbsN, 'r', encoding="utf-8") as csvfile:
    cbsN_reader = csv.reader(csvfile)
    for i,row in enumerate(cbsN_reader):
        if i != 0 and i != 8:
            cbsN2_time.append(float(row[2]))
            cbsN2_generate.append(int(row[3]))
            cbsN2_expand.append(int(row[4]))

# %%
dgN_time = []
dgN_generate = []
dgN_expand = []
with open(dgN, 'r', encoding="utf-8") as csvfile:
    dgN_reader = csv.reader(csvfile)
    for i,row in enumerate(dgN_reader):
        if i != 0:
            dgN_time.append(float(row[2]))
            dgN_generate.append(int(row[3]))
            dgN_expand.append(int(row[4]))

# %%
dgN2_time = []
dgN2_generate = []
dgN2_expand = []
with open(dgN, 'r', encoding="utf-8") as csvfile:
    dgN_reader = csv.reader(csvfile)
    for i,row in enumerate(dgN_reader):
        if i != 0 and i != 8:
            dgN2_time.append(float(row[2]))
            dgN2_generate.append(int(row[3]))
            dgN2_expand.append(int(row[4]))

# %%
wdgN_time = []
wdgN_generate = []
wdgN_expand = []
with open(wdgN, 'r', encoding="utf-8") as csvfile:
    wdgN_reader = csv.reader(csvfile)
    for i,row in enumerate(wdgN_reader):
        if i != 0:
            wdgN_time.append(float(row[2]))
            wdgN_generate.append(int(row[3]))
            wdgN_expand.append(int(row[4]))

# %%
wdgN2_time = []
wdgN2_generate = []
wdgN2_expand = []
with open(wdgN, 'r', encoding="utf-8") as csvfile:
    wdgN_reader = csv.reader(csvfile)
    for i,row in enumerate(wdgN_reader):
        if i != 0 and i != 8:
            wdgN2_time.append(float(row[2]))
            wdgN2_generate.append(int(row[3]))
            wdgN2_expand.append(int(row[4]))

# %%
lazyN_time = []
lazyN_generate = []
lazyN_expand = []
with open(lazyN, 'r', encoding="utf-8") as csvfile:
    lazyN_reader = csv.reader(csvfile)
    for i,row in enumerate(lazyN_reader):
        if i != 0:
            lazyN_time.append(float(row[2]))
            lazyN_generate.append(int(row[3]))
            lazyN_expand.append(int(row[4]))

# %%
lazyN2_time = []
lazyN2_generate = []
lazyN2_expand = []
with open(lazyN, 'r', encoding="utf-8") as csvfile:
    lazyN_reader = csv.reader(csvfile)
    for i,row in enumerate(lazyN_reader):
        if i != 0 and i != 8:
            lazyN2_time.append(float(row[2]))
            lazyN2_generate.append(int(row[3]))
            lazyN2_expand.append(int(row[4]))

# %%
cbsAvg_generate = []
cbsAvg_expand = []
dgAvg_generate = []
dgAvg_expand = []
wdgAvg_generate = []
wdgAvg_expand = []
cMax = []
with open(collisionMax, 'r', encoding="utf-8") as csvfile:
    collisionMax_reader = csv.reader(csvfile)
    for i,row in enumerate(collisionMax_reader):
        if i != 0:
            cMax.append(int(row[0]))
            cbsAvg_generate.append(float(row[1]))
            cbsAvg_expand.append(float(row[2]))
            dgAvg_generate.append(float(row[3]))
            dgAvg_expand.append(float(row[4]))
            wdgAvg_generate.append(float(row[5]))
            wdgAvg_expand.append(float(row[6]))

# %%
x = np.linspace(1, 49, 49)
x2 = np.linspace(1, 25, 25)
x3 = np.linspace(1, 24, 24)

# %%
# plt.plot(x, dg_brute_force_time, linestyle='', marker='.')
plt.plot(x, cbs_time, label='cbs')
plt.plot(x, dg_brute_force_time, label='Brute-Force')
plt.title('time')
plt.legend()

# %%
# plt.plot(x, dg_brute_force_time, linestyle='', marker='.')
plt.plot(x, cbs_generate, label='cbs')
plt.plot(x, dg_brute_force_generate, label='Brute-Force')
plt.title('generate')
plt.legend()

# %%
# plt.plot(x, dg_brute_force_time, linestyle='', marker='.')
plt.plot(x, cbs_expand, label='cbs')
plt.plot(x, dg_brute_force_expand, label='Brute-Force')
plt.title('expand')
plt.legend()

# %%
# plt.plot(x, dg_brute_force_time, linestyle='', marker='.')
plt.plot(x, dg_brute_force_time, label='Brute-Force')
plt.plot(x, dg_2_approx_time, label='2-Approximation')
plt.title('time')
plt.legend()

# %%
plt.plot(x, dg_brute_force_generate, label='Brute-Force')
plt.plot(x, dg_2_approx_generate, label='2-Approximation')
plt.title('generate')
plt.legend()

# %%
plt.plot(x, dg_brute_force_expand, label='Brute-Force')
plt.plot(x, dg_2_approx_expand, label='2-Approximation')
plt.title('expand')
plt.legend()

# %%
#plt.plot(x, dg_brute_force_time, label='Brute-Force')
#plt.plot(x, dg_2_approx_time, label='2-Approximation')
plt.plot(x, wdg_linear_time, label='WDG-Linear')
plt.plot(x, wdg_round_time, label='WDG-Round')
#plt.plot(x, iwdg_time, label='IWDG')
plt.plot(x, lazy_time, label='LAZY')
plt.title('time')
plt.legend()

# %%
#plt.plot(x, dg_brute_force_generate, label='Brute-Force')
#plt.plot(x, dg_2_approx_generate, label='2-Approximation')
plt.plot(x, wdg_linear_generate, label='WDG-Linear')
plt.plot(x, wdg_round_generate, label='WDG-Round')
#plt.plot(x, iwdg_generate, label='IWDG')
plt.plot(x, lazy_generate, label='LAZY')
plt.title('generate')
plt.legend()

# %%
#plt.plot(x, dg_brute_force_expand, label='Brute-Force')
#plt.plot(x, dg_2_approx_expand, label='2-Approximation')
plt.plot(x, wdg_linear_expand, label='WDG-Linear')
plt.plot(x, wdg_round_expand, label='WDG-Round')
#plt.plot(x, iwdg_expand, label='IWDG')
plt.plot(x, lazy_expand, label='LAZY')
plt.title('expand')
plt.legend()

# %%
#plt.plot(x, dg_brute_force_time, label='Brute-Force')
#plt.plot(x, dg_2_approx_time, label='2-Approximation')
plt.plot(x, dg_brute_force_time, label='Brute-Force')
plt.plot(x, wdg_round_time, label='WDG-Round')
#plt.plot(x, iwdg_time, label='IWDG')
plt.title('time')
plt.legend()

# %%
#plt.plot(x, dg_brute_force_time, label='Brute-Force')
#plt.plot(x, dg_2_approx_time, label='2-Approximation')
plt.plot(x, dg_brute_force_generate, label='Brute-Force')
plt.plot(x, wdg_round_generate, label='WDG-Round')
#plt.plot(x, iwdg_time, label='IWDG')
plt.title('generate')
plt.legend()

# %%
#plt.plot(x, dg_brute_force_time, label='Brute-Force')
#plt.plot(x, dg_2_approx_time, label='2-Approximation')
plt.plot(x, dg_brute_force_expand, label='Brute-Force')
plt.plot(x, wdg_round_expand, label='WDG-Round')
#plt.plot(x, iwdg_time, label='IWDG')
plt.title('expand')
plt.legend()

# %%
plt.plot(x3, cbsN2_time, label='cbs')
plt.plot(x3, dgN2_time, label='Brute-Force')
# plt.plot(x2, wdgN_time, label='WDG-Round')
# plt.plot(x2, lazyN_time, label='LAZY')
plt.title('time')
plt.legend()

# %%
plt.plot(x3, cbsN2_generate, label='cbs')
plt.plot(x3, dgN2_generate, label='Brute-Force')
# plt.plot(x2, wdgN_time, label='WDG-Round')
# plt.plot(x2, lazyN_time, label='LAZY')
plt.title('generate')
plt.legend()

# %%
plt.plot(x3, cbsN2_expand, label='cbs')
plt.plot(x3, dgN2_expand, label='Brute-Force')
# plt.plot(x2, wdgN_time, label='WDG-Round')
# plt.plot(x2, lazyN_time, label='LAZY')
plt.title('expand')
plt.legend()

# %%
plt.plot(x3, cbsN2_time, label='cbs')
plt.plot(x3, dgN2_time, label='Brute-Force')
plt.plot(x3, wdgN2_time, label='WDG-Round')
plt.plot(x3, lazyN2_time, label='LAZY')
plt.title('time')
plt.legend()

# %%
plt.plot(x3, cbsN2_generate, label='cbs')
plt.plot(x3, dgN2_generate, label='Brute-Force')
plt.plot(x3, wdgN2_generate, label='WDG-Round')
plt.plot(x3, lazyN2_generate, label='LAZY')
plt.title('generate')
plt.legend()

# %%
plt.plot(x3, cbsN2_expand, label='cbs')
plt.plot(x3, dgN2_expand, label='Brute-Force')
plt.plot(x3, wdgN2_expand, label='WDG-Round')
plt.plot(x3, lazyN2_expand, label='LAZY')
plt.title('expand')
plt.legend()

# %%
plt.plot(cMax[0:-2], cbsAvg_generate[0:-2], label='cbs', marker='.')
plt.plot(cMax[0:-2], dgAvg_generate[0:-2], label='Brute-Force', marker='.')
plt.plot(cMax[0:-2], wdgAvg_generate[0:-2], label='WDG-Round', marker='.')
plt.title('generate')
plt.legend()

# %%
plt.plot(cMax, cbsAvg_generate, label='cbs', marker='.')
plt.plot(cMax, dgAvg_generate, label='Brute-Force', marker='.')
plt.plot(cMax, wdgAvg_generate, label='WDG-Round', marker='.')
plt.title('generate')
plt.legend()

# %%
plt.plot(cMax[0:-2], cbsAvg_expand[0:-2], label='cbs', marker='.')
plt.plot(cMax[0:-2], dgAvg_expand[0:-2], label='Brute-Force', marker='.')
plt.plot(cMax[0:-2], wdgAvg_expand[0:-2], label='WDG-Round', marker='.')
plt.title('expand')
plt.legend()

# %%
plt.plot(cMax, cbsAvg_expand, label='cbs', marker='.')
plt.plot(cMax, dgAvg_expand, label='Brute-Force', marker='.')
plt.plot(cMax, wdgAvg_expand, label='WDG-Round', marker='.')
plt.title('expand')
plt.legend()
